# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path= "/content/drive/MyDrive/Instacart/Instacart.zip"
import zipfile
with zipfile.ZipFile(file_path, 'r') as zip_ref:
  zip_ref.extractall("/content/drive/MyDrive/Instacart/extracted_folder")

# %%
# !ls "/content/drive/MyDrive/Instacart/extracted_folder"
# Out:
# aisles.csv	 order_products__prior.csv  orders.csv
# departments.csv  order_products__train.csv  products.csv

# %%
import pandas as pd
aisles = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/aisles.csv")
products = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/products.csv")
order_products__prior = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/order_products__prior.csv")
departments = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/departments.csv")
order_products__train = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/order_products__train.csv")

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
orders = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/orders.csv")

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
orders.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
products.isnull().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %%
order_products__prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
order_products__train.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
aisles.isnull().sum()
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %%
departments.isnull().sum()
# Out:
# department_id    0
# department       0
# dtype: int64

# %%
orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
orders.dropna(subset = ['days_since_prior_order'],inplace = True)

# %%
orders.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %%
orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
# 5   3367565        1    prior             6          2                  7
#
#    days_since_prior_order
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
# 5                    19.0

# %%
orders = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/orders.csv")

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
orders['eval_set'].unique()
# Out:
# array(['prior', 'train', 'test'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
orders['eval_set_encoded'] = le.fit_transform(orders['eval_set'])

# %%
orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# eval_set_encoded            int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

orders['eval_set_encoded'] = le.fit_transform(orders['eval_set'])

print("Classes found by LabelEncoder:", le.classes_)
print("Encoded 'eval_set' values:\n", orders[['eval_set', 'eval_set_encoded']].head())
# Out:
# Classes found by LabelEncoder: ['prior' 'test' 'train']
# Encoded 'eval_set' values:
#    eval_set  eval_set_encoded
# 0    prior                 0
# 1    prior                 0
# 2    prior                 0
# 3    prior                 0
# 4    prior                 0

# %%
orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# eval_set_encoded            int64
# dtype: object

# %%
orders['eval_set'] = le.fit_transform(orders['eval_set'])

# %%
orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                    int64
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# eval_set_encoded            int64
# dtype: object

# %%
orders.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# eval_set_encoded               0
# dtype: int64

# %%
orders.dropna(subset = ['days_since_prior_order'],inplace = True)

# %%
orders.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# eval_set_encoded          0
# dtype: int64

# %%
orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                    int64
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# eval_set_encoded            int64
# dtype: object

# %%
orders['days_since_prior_order']= orders['days_since_prior_order'].astype('int')

# %%
orders.dtypes
# Out:
# order_id                  int64
# user_id                   int64
# eval_set                  int64
# order_number              int64
# order_dow                 int64
# order_hour_of_day         int64
# days_since_prior_order    int64
# eval_set_encoded          int64
# dtype: object

# %%
orders.head()
# Out:
#    order_id  user_id  eval_set  order_number  order_dow  order_hour_of_day  \
# 1   2398795        1         0             2          3                  7
# 2    473747        1         0             3          3                 12
# 3   2254736        1         0             4          4                  7
# 4    431534        1         0             5          4                 15
# 5   3367565        1         0             6          2                  7
#
#    days_since_prior_order  eval_set_encoded
# 1                      15                 0
# 2                      21                 0
# 3                      29                 0
# 4                      28                 0
# 5                      19                 0

# %%
products = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/products.csv")

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
products.isnull().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %%
products.dtypes
# Out:
# product_id        int64
# product_name     object
# aisle_id          int64
# department_id     int64
# dtype: object

# %%
import pandas as pd

aisle_id = pd.read_csv ("/content/drive/MyDrive/Instacart/extracted_folder/aisles.csv")

# %%
# !ls "/content/drive/MyDrive/Instacart/extracted_folder/"
# Out:
# aisles.csv	 order_products__prior.csv  orders.csv
# departments.csv  order_products__train.csv  products.csv

# %%
aisle_id.isnull().sum()
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %%
aisle_id.dtypes
# Out:
# aisle_id     int64
# aisle       object
# dtype: object

# %%
departments = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/departments.csv")

# %%
departments.isnull().sum()
# Out:
# department_id    0
# department       0
# dtype: int64

# %%
departments.dtypes
# Out:
# department_id     int64
# department       object
# dtype: object

# %%
order_products__prior = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/order_products__prior.csv")

# %%
order_products__prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
order_products__prior.dtypes
# Out:
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtype: object

# %%
order_products__train = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/order_products__train.csv")

# %%
order_products__train.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
order_products__train.dtypes
# Out:
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtype: object

# %%
duplicates = order_products__train.duplicated

# %%
order_products__train[duplicates]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
duplicates = order_products__prior.duplicated(keep=False)
duplicate_rows = order_products__prior[duplicates]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
duplicates = orders.duplicated(keep=False)
duplicate_rows = orders[duplicates]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, order_dow, order_hour_of_day, days_since_prior_order, eval_set_encoded]
# Index: []

# %%
products = pd.read_csv("/content/drive/MyDrive/Instacart/extracted_folder/products.csv")
duplicates = products.duplicated(keep=False)
duplicate_rows = products[duplicates]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
duplicates = departments.duplicated(keep=False)
duplicate_rows = departments[duplicates]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %%
duplicates = aisle_id.duplicated(keep=False)
duplicate_rows = aisle_id[duplicates]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %%
duplicates = order_products__train.duplicated(keep=False)
duplicate_rows = order_products__train[duplicates]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
duplicates = order_products__prior.duplicated(keep=False)
duplicate_rows = order_products__prior[duplicates]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
prior_merged = pd.merge(order_products__prior, products, on='product_id', how='left')

# %%
prior_merged.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id
# 0        86             16
# 1        83              4
# 2       104             13
# 3        19             13
# 4        17             13

# %%
prior_merged = prior_merged.merge(aisle_id, on='aisle_id', how='left')

# %%
prior_merged.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id               aisle
# 0        86             16                eggs
# 1        83              4    fresh vegetables
# 2       104             13   spices seasonings
# 3        19             13       oils vinegars
# 4        17             13  baking ingredients

# %%
prior_merged = prior_merged.merge(departments, on='department_id', how='left')

# %%
prior_merged.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id               aisle  department
# 0        86             16                eggs  dairy eggs
# 1        83              4    fresh vegetables     produce
# 2       104             13   spices seasonings      pantry
# 3        19             13       oils vinegars      pantry
# 4        17             13  baking ingredients      pantry

# %%
import pandas as pd

# %%
full_data = pd.merge(prior_merged, orders, on='order_id', how='left')
